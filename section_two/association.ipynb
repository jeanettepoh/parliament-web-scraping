# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_file = os.path.join(os.getcwd(), "data", "residential_data.csv")
df = pd.read_csv(data_file)
df['transaction_date'] = pd.to_datetime(df['transaction_date'])
df['Year'] = df['transaction_date'].dt.year
# Out:
# /var/folders/3f/xhw3kd5d62v0s4_2fvl3_7480000gn/T/ipykernel_91946/3792354289.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['transaction_date'] = pd.to_datetime(df['transaction_date'])

# %%
df
# Out:
#        salesperson_name transaction_date salesperson_reg_num  \
# 0           SOH HUI HUA       2017-10-01            P000003I
# 1           SOH HUI HUA       2018-03-01            P000003I
# 2           SOH HUI HUA       2017-01-01            P000003I
# 3           SOH HUI HUA       2018-05-01            P000003I
# 4           SOH HUI HUA       2017-11-01            P000003I
# ...                 ...              ...                 ...
# 954201                -       2020-02-01                   -
# 954202                -       2020-02-01                   -
# 954203                -       2020-01-01                   -
# 954204                -       2020-02-01                   -
# 954205                -       2020-02-01                   -
#
#                  property_type transaction_type represented             town  \
# 0                          HDB           RESALE      SELLER           YISHUN
# ...

# %%
df = df[(df["represented"] == "SELLER") & (df["transaction_type"] == "RESALE")]
df
# Out:
#        salesperson_name transaction_date salesperson_reg_num  \
# 0           SOH HUI HUA       2017-10-01            P000003I
# 3           SOH HUI HUA       2018-05-01            P000003I
# 4           SOH HUI HUA       2017-11-01            P000003I
# 5           SOH HUI HUA       2018-08-01            P000003I
# 6           SOH HUI HUA       2018-08-01            P000003I
# ...                 ...              ...                 ...
# 954132                -       2023-12-01                   -
# 954165                -       2023-12-01                   -
# 954173                -       2023-12-01                   -
# 954196                -       2023-12-01                   -
# 954205                -       2020-02-01                   -
#
#                  property_type transaction_type represented           town  \
# 0                          HDB           RESALE      SELLER         YISHUN
# 3                          HDB           RESALE      SELLER  CHOA CHU KANG
# ...

# %%
df = df[df["salesperson_name"] != "-"]
df
# Out:
#                salesperson_name transaction_date salesperson_reg_num  \
# 0                   SOH HUI HUA       2017-10-01            P000003I
# 3                   SOH HUI HUA       2018-05-01            P000003I
# 4                   SOH HUI HUA       2017-11-01            P000003I
# 5                   SOH HUI HUA       2018-08-01            P000003I
# 6                   SOH HUI HUA       2018-08-01            P000003I
# ...                         ...              ...                 ...
# 951729            YAP CHEN CHEN       2024-05-01            R069426A
# 951767               LI JIANING       2024-05-01            R069968I
# 951777       AXEL ANG MING JING       2024-06-01            R069897E
# 951783  KAM HWAY FONG JACQUELYN       2024-06-01            R070053Z
# 951816             TAN WEI CHEW       2024-06-01            R069908J
#
#                  property_type transaction_type represented           town  \
# ...

# %%
df["salesperson_name"].value_counts()
# Out:
# salesperson_name
# KUAH KAI PIN, KAVIN           1647
# CHEE KOK LEONG                 719
# MUHAMAD SOFIAN BIN ROSLAN      700
# NOOR HAIDI BIN ABDUL MALEK     551
# YUNA LIM                       506
#                               ...
# TAY CHIANG CHEW                  1
# TOK SHIRLEY                      1
# TEO BEE HUA LINDA                1
# TAN WEE LUEN MARCEL              1
# TAN WEI CHEW                     1
# Name: count, Length: 21735, dtype: int64

# %%
df["Year"].value_counts()
# Out:
# Year
# 2021    48267
# 2022    40378
# 2023    38228
# 2020    31511
# 2018    22405
# 2019    19410
# 2024    19065
# 2017    18670
# Name: count, dtype: int64

# %%
# Directory to save figures
save_dir = "figures"
os.makedirs(save_dir, exist_ok=True)

# %%
# Get unique years from the Year column
unique_years = df['Year'].unique()

# Loop over unique years
for year in unique_years:
    # Filter data for the current year
    df_filtered = df[df['Year'] == year]
    
    # Count number of rows (transactions) for each agent
    agent_counts = df_filtered['salesperson_name'].value_counts()
    
    # Plotting the distribution of number of transactions by agent for the current year
    plt.figure(figsize=(8, 5))
    plt.bar(agent_counts.index, agent_counts.values, color='red')
    plt.title(f'Distribution for Number of Sales in {year}')
    plt.xlabel('Agent')
    plt.ylabel('Number of Transactions')
    plt.xticks([])  # Remove x-axis ticks
    # Set y-axis limit to max value + 10
    print(agent_counts.max())
    plt.ylim(0, agent_counts.max() + 10)
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, f"Sales_Distribution_for_{year}.png"))
    plt.show()
# Out:
# 170
# 205
# 170
# 226
# 303
# 261
# 199
# 113
